# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import ast

# %%
data = pd.read_csv(os.path.join("logs", 'sim_no-learning.csv'))

# %%
#data['average_reward'] = (data['net_reward'] / (data['initial_deadline'] - data['final_deadline']))\
#.rolling(window=10, center=False).mean()
(data['net_reward']/(data['initial_deadline'] - data['final_deadline']))
# Out:
# 0    -12.937516
# 1     -0.434048
# 2     -6.080473
# 3     -4.760014
# 4     -3.920250
# 5     -3.372207
# 6     -4.376419
# 7     -2.527360
# 8     -2.478747
# 9     -2.956945
# 10    -8.510437
# 11    -4.219199
# 12    -1.760614
# 13    -2.179042
# 14    -3.051794
# 15    -0.605614
# 16    -0.571002
# 17    -2.306092
# 18    -6.643746
# 19    -3.468075
# 20    -5.318445
# 21    -4.414274
# 22    -7.440995
# 23    -3.936372
# 24    -5.378256
# 25    -3.835104
# 26    -6.333567
# 27    -4.223663
# 28    -5.552909
# 29    -2.874944
# dtype: float64

# %% [markdown]
# #### From here, what you can see is pd.rolling literally takes that window span and sums that up.. and then when you take mean(), it finds the mean of window 0-9.. refer here
# [Pandas Rolling Objects](https://stackoverflow.com/questions/45254174/how-do-pandas-rolling-objects-work)

# %%
(data['net_reward']/(data['initial_deadline'] - data['final_deadline'])).rolling(window=10, center=False).mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9    -4.384398
# 10   -3.941690
# 11   -4.320205
# 12   -3.888219
# 13   -3.630122
# 14   -3.543277
# 15   -3.266617
# 16   -2.886076
# 17   -2.863949
# 18   -3.280449
# 19   -3.331562
# 20   -3.012362
# 21   -3.031870
# 22   -3.599908
# 23   -3.775641
# 24   -4.008287
# 25   -4.331236
# 26   -4.907493
# 27   -5.099250
# 28   -4.990166
# 29   -4.930853
# dtype: float64

# %%
# this is a rolling relative frequency.. If you want a average/frequency for each trial within the given time limit, then you have to remove the .rolling
# portion. It's literally a comparison of the past 10 average/frequency within the given time limit
((data['actions'].apply(lambda x: ast.literal_eval(x)[0]))*1.0/\
(data['initial_deadline'] - data['final_deadline'])).rolling(window=10, center=False).mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     0.628303
# 10    0.648859
# 11    0.645287
# 12    0.638287
# 13    0.646287
# 14    0.649620
# 15    0.673620
# 16    0.696954
# 17    0.696954
# 18    0.686954
# 19    0.688317
# 20    0.689429
# 21    0.662000
# 22    0.654000
# 23    0.648000
# 24    0.630667
# 25    0.606667
# 26    0.576667
# 27    0.575303
# 28    0.580303
# 29    0.580303
# dtype: float64

# %%
d_test = {'forward': 0.345, 'left': 0.34, 'right': 0.345}
d_test.keys()
# Out:
# ['forward', 'right', 'left']

# %%
max_key = [d for d in d_test.keys() if d_test[d] == max(d_test.values())]

# %%
max_key
# Out:
# ['forward', 'right']

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import exp

# %%
max(d_test.values())
# Out:
# 0.345

# %%
a = 0.5
time = np.linspace(1,10,100)

fig = plt.figure(figsize=(12,6))

ax = fig.add_axes([0,0,1,1])

ax.set_title('Decay function vs time')
ax.plot(time, a**time, label="a**t")
ax.plot(time, 1.0/time**2, label="1/t**2")
ax.plot(time, np.exp(-a*time),label="e**-at")
ax.plot(time, np.cos(a*time),label="cos(at)")
ax.legend()
fig

# %%
a = np.linspace(0,1,100)
time = 1

fig = plt.figure(figsize=(12,6))

ax = fig.add_axes([0,0,1,1])

ax.set_title('Decay function vs alpha values')

intersection = {x:y for x in a if x**time==}

ax.plot(a, a**time, label="a**t")
ax.plot(a, np.exp(-a*time),label="e**-at")
ax.legend()
fig

# %%
a**time is np.exp(-a*time)
# Out:
# False
